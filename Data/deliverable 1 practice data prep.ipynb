# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
file = "Resources/ShelterDogs.csv"
df = pd.read_csv(file)
df.head()
# Out:
#       ID            name   age     sex               breed  date_found  \
# 0  23807            Gida  0.25  female         Unknown Mix  2019-12-10
# 1    533  Frida És Ricsi  0.17  female         Unknown Mix  2019-12-01
# 2  23793             NaN  4.00    male         Unknown Mix  2019-12-08
# 3  23795             NaN  1.00    male         Unknown Mix  2019-12-08
# 4  23806             Amy  2.00  female  French Bulldog Mix  2019-12-10
#
#   adoptable_from      posted            color    coat    size neutered  \
# 0     2019-12-11  2019-12-11              red   short   small       no
# 1     2019-12-01  2019-12-09  black and white   short   small       no
# 2     2019-12-23  2019-12-08      saddle back   short  medium       no
# 3     2019-12-23  2019-12-08     yellow-brown  medium  medium       no
# 4     2019-12-11  2019-12-11            black   short   small       no
#
#   housebroken likes_people likes_children get_along_males get_along_females  \
# ...

# %%
practice_df = df[['ID', 'adoptable_from', 'age']]

# %%
practice_df.head()
# Out:
#       ID adoptable_from   age
# 0  23807     2019-12-11  0.25
# 1    533     2019-12-01  0.17
# 2  23793     2019-12-23  4.00
# 3  23795     2019-12-23  1.00
# 4  23806     2019-12-11  2.00

# %%
practice_df2 = df[['ID', 'adoptable_from', 'likes_people', 'likes_children', 'get_along_males', 'get_along_females', 'get_along_cats']]

# %%
practice_df2.head()
#### need to revisit later to assess for volume of null values
# Out:
#       ID adoptable_from likes_people likes_children get_along_males  \
# 0  23807     2019-12-11          NaN            NaN             NaN
# 1    533     2019-12-01          yes            yes             yes
# 2  23793     2019-12-23          NaN            NaN             NaN
# 3  23795     2019-12-23          NaN            NaN             NaN
# 4  23806     2019-12-11          NaN            NaN             NaN
#
#   get_along_females get_along_cats
# 0               NaN            NaN
# 1               yes            yes
# 2               NaN            NaN
# 3               NaN            NaN
# 4               NaN            NaN
